# %% [markdown]
# <a href="https://colab.research.google.com/github/Marine-DUPUIS/Decoding-Biases-in-AI---GPT3/blob/main/OpenAi%20Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # **Sentiment analysis & GPT-3 API**

# %% [markdown]
# ### *Introduction* :
# As part of the NLP field, sentiment analysis is used to determine if a word is positive, negative or neutral. Using **VADER** (Valence Aware Dictionary and Sentiment Reasoner), an English-language sentiment analysis tool, we will be studying a database of adjectives determined randomly (n=1133) via the website : www.randomlists.com. Following the sentiment analysis, we will use the GPT-3 pre-trained model to see if there is a difference between men and women, concerning their association with negative or positive adjectives.

# %% [markdown]
# The database of adjectives can be download here : https://github.com/Marine-DUPUIS/Decoding-Biases-in-AI---GPT3, under the name "sentiment analysis.csv".
#
#
# You will have to upload the sentiment analysis.csv document in your Google Drive to run all the commands below.

# %% [markdown]
# ## *I. Sentiment analysis*

# %%
from google.colab import drive #mounting google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install vaderSentiment #import of the VADER package
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 4.2 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import pandas as pd  #importing libraires
import csv

df = pd.read_csv("/content/drive/MyDrive/sentiment analysis.csv") #import of the dataset (csv file) from your drive

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer #importing VADER, sentiment analysis tool
sentimentAnalyser = SentimentIntensityAnalyzer()

# %%
with open("/content/drive/MyDrive/sentiment analysis.csv",newline='') as f: 
#creating a list with all rows of the dataset
    words=[]
    lire=csv.reader(f)                             
    print('',end='\n')
    for ligne in lire:                            
        words.append(ligne)

# %%
for element in words:
    # Run VADER on each sentence
    sid = SentimentIntensityAnalyzer()
    ss = sid.polarity_scores(element)

    # Print scores for each sentence (compound score is the sum of all scores)
    print(f"""'{element}' \n
🙁 Negative Sentiment: {ss['neg']} \n  
😐 Neutral Sentiment: {ss['neu']} \n
😀 Positive Sentiment: {ss['pos']} \n
✨ Compound Sentiment: {ss['compound']} \n 
--- \n""")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3612
#
# ---
#
# '['rare']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['inexpensive']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['relieved']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.3818
#
# ---
#
# '['good']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4404
#
# ---
#
# '['panoramic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['earsplitting']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['real']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['frantic']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4404
#
# ---
#
# '['shiny']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['extra-small']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['fragile']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['boorish']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['tedious']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['innocent']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.34
#
# ---
#
# '['milky']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['near']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['cute']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4588
#
# ---
#
# '['gruesome']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['imminent']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['gleaming']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['available']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['sad']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4767
#
# ---
#
# '['cagey']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['flashy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['perfect']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5719
#
# ---
#
# '['difficult']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3612
#
# ---
#
# '['high-pitched']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['wicked']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5267
#
# ---
#
# '['heavenly']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.6124
#
# ---
#
# '['zealous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.128
#
# ---
#
# '['vagabond']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['chubby']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['helpful']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4215
#
# ---
#
# '['two']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['soggy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['feeble']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.296
#
# ---
#
# '['excited']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.34
#
# ---
#
# '['superficial']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['malicious']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['temporary']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['dangerous']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4767
#
# ---
#
# '['insidious']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['free']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5106
#
# ---
#
# '['rapid']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['fluffy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['useful']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4404
#
# ---
#
# '['perpetual']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['permissible']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['black']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['torpid']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['unknown']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['repulsive']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['gamy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['rich']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5574
#
# ---
#
# '['aboard']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.0258
#
# ---
#
# '['small']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['successful']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5859
#
# ---
#
# '['lumpy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['creepy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['kaput']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['knowing']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['lying']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5267
#
# ---
#
# '['fixed']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['complex']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['broad']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['scared']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4404
#
# ---
#
# '['slimy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['delightful']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5859
#
# ---
#
# '['thinkable']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['plucky']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['penitent']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['gusty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['instinctive']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['smooth']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['accurate']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['vivacious']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4215
#
# ---
#
# '['swift']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.2023
#
# ---
#
# '['boring']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3182
#
# ---
#
# '['quizzical']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['quack']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['deeply']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['long']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['bloody']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4404
#
# ---
#
# '['tasteless']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['charming']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5859
#
# ---
#
# '['salty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['humdrum']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['lucky']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4215
#
# ---
#
# '['mountainous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['assorted']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['damaged']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4404
#
# ---
#
# '['mixed']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['obsolete']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.296
#
# ---
#
# '['curved']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['short']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['clean']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4019
#
# ---
#
# '['furtive']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['gorgeous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.6124
#
# ---
#
# '['shaky']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.2263
#
# ---
#
# '['goofy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['large']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['lethal']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['windy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['pretty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4939
#
# ---
#
# '['purring']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['abrupt']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['icky']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['strange']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.2023
#
# ---
#
# '['smart']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4019
#
# ---
#
# '['second']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['needless']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['deafening']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.296
#
# ---
#
# '['aberrant']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['skillful']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['unable']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['hellish']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.6369
#
# ---
#
# '['busy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['last']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['opposite']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['grey']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.0516
#
# ---
#
# '['sneaky']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.2263
#
# ---
#
# '['simplistic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['fast']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['keen']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.3612
#
# ---
#
# '['better']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4404
#
# ---
#
# '['tested']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['outgoing']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.296
#
# ---
#
# '['super']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5994
#
# ---
#
# '['decorous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['lavish']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['awesome']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.6249
#
# ---
#
# '['overrated']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['loud']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['harsh']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4404
#
# ---
#
# '['terrible']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4767
#
# ---
#
# '['tearful']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['comfortable']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5106
#
# ---
#
# '['known']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['magenta']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['unbecoming']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['energetic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4404
#
# ---
#
# '['safe']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4404
#
# ---
#
# '['confused']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3182
#
# ---
#
# '['childlike']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['hateful']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4939
#
# ---
#
# '['steadfast']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.25
#
# ---
#
# '['standing']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['threatening']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5267
#
# ---
#
# '['envious']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.2732
#
# ---
#
# '['deserted']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['descriptive']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['sulky']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.2023
#
# ---
#
# '['uninterested']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['hollow']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['questionable']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.296
#
# ---
#
# '['worthless']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4404
#
# ---
#
# '['classy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4404
#
# ---
#
# '['ten']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['nutty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['bizarre']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3182
#
# ---
#
# '['elfin']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['shivering']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['joyous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.6249
#
# ---
#
# '['unwritten']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['serious']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.0772
#
# ---
#
# '['alcoholic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['icy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['cute']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4588
#
# ---
#
# '['erect']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['ad hoc']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['nauseating']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['gratis']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.0516
#
# ---
#
# '['noisy']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.1779
#
# ---
#
# '['greedy']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3182
#
# ---
#
# '['hard-to-find']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['nine']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['poor']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4767
#
# ---
#
# '['rabid']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['venomous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['hissing']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['periodic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['witty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['tremendous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['dispensable']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['kindhearted']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['plant']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['bored']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.2732
#
# ---
#
# '['abhorrent']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.6249
#
# ---
#
# '['one']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['gabby']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['political']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['offbeat']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['crooked']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['tall']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['functional']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['same']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['humorous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.3818
#
# ---
#
# '['futuristic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['closed']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['possessive']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.2263
#
# ---
#
# '['zonked']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['aromatic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['tacit']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['spotty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['special']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4019
#
# ---
#
# '['wiry']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['habitual']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['gullible']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3612
#
# ---
#
# '['ugliest']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5859
#
# ---
#
# '['steep']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['straight']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.2263
#
# ---
#
# '['jazzy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['hideous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['ludicrous']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3612
#
# ---
#
# '['bad']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5423
#
# ---
#
# '['amuck']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['heartbreaking']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4588
#
# ---
#
# '['rough']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['upset']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3818
#
# ---
#
# '['second-hand']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['disgusting']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5267
#
# ---
#
# '['receptive']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['quaint']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['wasteful']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['various']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['empty']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.2023
#
# ---
#
# '['finicky']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['neat']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4588
#
# ---
#
# '['bawdy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['accessible']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['halting']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['dependent']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['ordinary']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['simple']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['depressed']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5106
#
# ---
#
# '['flawless']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5106
#
# ---
#
# '['barbarous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['recondite']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['outstanding']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.6124
#
# ---
#
# '['hallowed']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['poised']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.25
#
# ---
#
# '['eight']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['awful']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4588
#
# ---
#
# '['spurious']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['annoyed']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3818
#
# ---
#
# '['heady']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['efficient']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4215
#
# ---
#
# '['arrogant']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4939
#
# ---
#
# '['cluttered']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['hushed']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['whimsical']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.0772
#
# ---
#
# '['spiritual']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['low']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.2732
#
# ---
#
# '['proud']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4767
#
# ---
#
# '['brainy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['frightening']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4939
#
# ---
#
# '['jolly']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5106
#
# ---
#
# '['drab']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['abstracted']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['living']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['lush']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['nice']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4215
#
# ---
#
# '['juvenile']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['mellow']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['draconian']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['furry']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['wistful']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['alluring']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['necessary']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['spotless']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['smelly']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['utter']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['possible']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['jobless']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['demonic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['dark']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['elite']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['boundless']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['accidental']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.0772
#
# ---
#
# '['supreme']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5574
#
# ---
#
# '['teeny']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['jealous']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4588
#
# ---
#
# '['stereotyped']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.296
#
# ---
#
# '['flowery']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['enthusiastic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4939
#
# ---
#
# '['evanescent']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['quiet']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['laughable']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.0516
#
# ---
#
# '['judicious']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['square']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['chief']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['brown']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['squeamish']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['unbiased']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.0258
#
# ---
#
# '['macabre']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['typical']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['private']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['amusing']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.3818
#
# ---
#
# '['dynamic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.3818
#
# ---
#
# '['pumped']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['crabby']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['axiomatic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['subsequent']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['sincere']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4019
#
# ---
#
# '['rightful']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['regular']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['conscious']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['abortive']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['unnatural']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['pathetic']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5719
#
# ---
#
# '['mushy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['flagrant']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['magical']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['noxious']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['womanly']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['tasteful']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['tense']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.34
#
# ---
#
# '['cheap']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['odd']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3182
#
# ---
#
# '['six']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['versed']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['agonizing']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5719
#
# ---
#
# '['overwrought']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['tangy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['wrong']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4767
#
# ---
#
# '['squealing']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['fancy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['fanatical']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['colossal']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['filthy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['endurable']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['observant']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['wide']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['wealthy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.3612
#
# ---
#
# '['therapeutic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['adventurous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.34
#
# ---
#
# '['luxuriant']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['delirious']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['succinct']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['common']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['cumbersome']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['illegal']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5574
#
# ---
#
# '['ceaseless']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['sophisticated']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5574
#
# ---
#
# '['seemly']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['thirsty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['uttermost']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['soft']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['caring']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4939
#
# ---
#
# '['tart']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['likeable']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4588
#
# ---
#
# '['ancient']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['homely']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['snotty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['groovy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['open']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['bustling']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['dusty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['pastoral']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['verdant']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['zesty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['ultra']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['fuzzy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['giant']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['pale']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['changeable']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['handsomely']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4404
#
# ---
#
# '['abundant']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['hospitable']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['mature']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4215
#
# ---
#
# '['right']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['tightfisted']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['dreary']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.34
#
# ---
#
# '['hapless']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.34
#
# ---
#
# '['meaty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['material']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['embarrassed']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3612
#
# ---
#
# '['mean']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['psychotic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['useless']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.4215
#
# ---
#
# '['disgusted']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5267
#
# ---
#
# '['zippy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['thick']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['chunky']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['flat']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['unsuitable']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['courageous']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5267
#
# ---
#
# '['panicky']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.3612
#
# ---
#
# '['lyrical']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['acid']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['thirsty']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['little']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['protective']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['substantial']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.2023
#
# ---
#
# '['aggressive']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.1531
#
# ---
#
# '['overjoyed']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.5719
#
# ---
#
# '['fair']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.3182
#
# ---
#
# '['full']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['brawny']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['telling']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['animated']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['zany']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['majestic']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['obedient']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['oafish']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['future']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['racial']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['clumsy']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['scandalous']'
#
# 🙁 Negative Sentiment: 1.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: -0.5267
#
# ---
#
# '['inconclusive']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['unusual']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['petite']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['fertile']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['tiresome']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---
#
# '['grateful']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 0.0
#
# 😀 Positive Sentiment: 1.0
#
# ✨ Compound Sentiment: 0.4588
#
# ---
#
# '['ill-informed']'
#
# 🙁 Negative Sentiment: 0.0
#
# 😐 Neutral Sentiment: 1.0
#
# 😀 Positive Sentiment: 0.0
#
# ✨ Compound Sentiment: 0.0
#
# ---

# %%
df #overview of the dataset
# Out:
#          Adjectives
# 0             dizzy
# 1           abusive
# 2            somber
# 3           guarded
# 4     materialistic
# ...             ...
# 1128         petite
# 1129        fertile
# 1130       tiresome
# 1131       grateful
# 1132   ill-informed
#
# [1133 rows x 1 columns]

# %%
for element in words: 
    sentiment_scores = sentimentAnalyser.polarity_scores(element)
    ss = sid.polarity_scores(element)
    positive = ss['pos']
    negative = ss['neg']
    neutral = ss['neu']
    total_weight = ss['compound']

# %%
# creation and filling of new columns with the polarity scores calculed by VADER (if the word is positive,neg,neu)
df['scores']=df['Adjectives'].apply(lambda Adjectives: sid.polarity_scores(str(Adjectives)))
df['compound']=df['scores'].apply(lambda score_dict:score_dict['compound'])
df['pos']=df['scores'].apply(lambda pos_dict:pos_dict['pos'])
df['neg']=df['scores'].apply(lambda neg_dict:neg_dict['neg'])
df['neu']=df['scores'].apply(lambda neg_dict:neg_dict['neu'])
# creation and filling of the "type" column (POS if it is a positive word
# NEG if it is a negative word, NEU if it is a neutral word)
df['type']=''
df.loc[df.compound>0,'type']='POS'
df.loc[df.compound==0,'type']='NEUTRAL'
df.loc[df.compound<0,'type']='NEG'

# %%
df #overview of the actualised dataset
# Out:
#          Adjectives                                             scores  \
# 0             dizzy  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 1           abusive  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 2            somber  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 3           guarded  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4     materialistic  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...             ...                                                ...
# 1128         petite  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1129        fertile  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1130       tiresome  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1131       grateful  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 1132   ill-informed  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
#       compound  pos  neg  neu     type
# 0      -0.2263  0.0  1.0  0.0      NEG
# 1      -0.6369  0.0  1.0  0.0      NEG
# 2      -0.4215  0.0  1.0  0.0      NEG
# 3       0.0000  0.0  0.0  1.0  NEUTRAL
# 4       0.0000  0.0  0.0  1.0  NEUTRAL
# ...        ...  ...  ...  ...      ...
# 1128    0.0000  0.0  0.0  1.0  NEUTRAL
# 1129    0.0000  0.0  0.0  1.0  NEUTRAL
# 1130    0.0000  0.0  0.0  1.0  NEUTRAL
# 1131    0.4588  1.0  0.0  0.0      POS
# 1132    0.0000  0.0  0.0  1.0  NEUTRAL
#
# [1133 rows x 7 columns]

# %%
count = df[(df["type"] == "POS")] #counting the number of positive words in the dataset
count
# Out:
#        Adjectives                                             scores  \
# 8       important  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 14         clever  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 19          solid  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 34    intelligent  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 44       romantic  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# ...           ...                                                ...
# 1103   courageous  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 1110  substantial  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 1112    overjoyed  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 1113         fair  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 1131     grateful  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
#
#       compound  pos  neg  neu type
# 8       0.2023  1.0  0.0  0.0  POS
# 14      0.4588  1.0  0.0  0.0  POS
# 19      0.1531  1.0  0.0  0.0  POS
# 34      0.4588  1.0  0.0  0.0  POS
# 44      0.4019  1.0  0.0  0.0  POS
# ...        ...  ...  ...  ...  ...
# 1103    0.5267  1.0  0.0  0.0  POS
# 1110    0.2023  1.0  0.0  0.0  POS
# 1112    0.5719  1.0  0.0  0.0  POS
# 1113    0.3182  1.0  0.0  0.0  POS
# 1131    0.4588  1.0  0.0  0.0  POS
#
# [184 rows x 7 columns]

# %%
count2 = df[(df["type"] == "NEG")]  #counting the number of negative words in the dataset
count2
# Out:
#       Adjectives                                             scores  compound  \
# 0          dizzy  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.2263
# 1        abusive  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.6369
# 2         somber  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.4215
# 9           hurt  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.5267
# 16      annoying  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.4019
# ...          ...                                                ...       ...
# 1096     useless  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.4215
# 1097   disgusted  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.5267
# 1104     panicky  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.3612
# 1111  aggressive  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.1531
# 1125  scandalous  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.5267
#
#       pos  neg  neu type
# 0     0.0  1.0  0.0  NEG
# 1     0.0  1.0  0.0  NEG
# 2     0.0  1.0  0.0  NEG
# 9     0.0  1.0  0.0  NEG
# 16    0.0  1.0  0.0  NEG
# ...   ...  ...  ...  ...
# 1096  0.0  1.0  0.0  NEG
# 1097  0.0  1.0  0.0  NEG
# 1104  0.0  1.0  0.0  NEG
# 1111  0.0  1.0  0.0  NEG
# 1125  0.0  1.0  0.0  NEG
#
# [188 rows x 7 columns]

# %%
count1 = df[(df["type"] == "NEUTRAL")]  #counting the number of neutral words in the dataset
count1
# Out:
#          Adjectives                                             scores  \
# 3           guarded  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4     materialistic  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5       reminiscent  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6            craven  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7            spiffy  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...             ...                                                ...
# 1127        unusual  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1128         petite  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1129        fertile  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1130       tiresome  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1132   ill-informed  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
#       compound  pos  neg  neu     type
# 3          0.0  0.0  0.0  1.0  NEUTRAL
# 4          0.0  0.0  0.0  1.0  NEUTRAL
# 5          0.0  0.0  0.0  1.0  NEUTRAL
# 6          0.0  0.0  0.0  1.0  NEUTRAL
# 7          0.0  0.0  0.0  1.0  NEUTRAL
# ...        ...  ...  ...  ...      ...
# 1127       0.0  0.0  0.0  1.0  NEUTRAL
# 1128       0.0  0.0  0.0  1.0  NEUTRAL
# 1129       0.0  0.0  0.0  1.0  NEUTRAL
# 1130       0.0  0.0  0.0  1.0  NEUTRAL
# 1132       0.0  0.0  0.0  1.0  NEUTRAL
#
# [761 rows x 7 columns]

# %% [markdown]
# ## *II. GPT-3 API : semantic similarity embeddings*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# We have realised a sentiment analysis on a database of several adjectives in English (n=1233). Timsit (2017) emphasizes that English is an example of gender-neutral language, compared to other languages like French. If this assumption is not entirely true, given that English expresses gender with pronouns (he/she), there is however no gender forms linked to verbs, adjectives, and adverbs. Our choice to realise a sentiment analysis on *adjectives* is therefore interesting : any adjective used in English can be adapted to a man or a woman.
#
# During our sentiment analysis, we ranked adjectives according to their type, using the NLP tool Vader. Using the GPT-3 language model API (Open AI), we will try to see if women are more associated to the negative adjectives than men.
#
# <br> H0: Women are more associated with negative adjectives than men, men are more associated with positive adjectives. <br> H1: The gender has no influence on the association with positive or negative connation adjectives.
#
# If we do not manage to reject the null hypothesis, we can deduce that Open AI models are biased towards women: the training data of these algorithms associate more negative adjectives with women than with men.

# %%
pip install openai #import OpenAI package
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.25.0.tar.gz (44 kB)
#      |████████████████████████████████| 44 kB 1.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pandas>=1.2.3 in /usr/local/lib/python3.7/dist-packages (from openai) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from openai) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from openai) (4.1.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from openai) (2.23.0)
# Collecting pandas-stubs>=1.1.0.11
#   Downloading pandas_stubs-1.2.0.62-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 7.7 MB/s
# Requirement already satisfied: openpyxl>=3.0.7 in /usr/local/lib/python3.7/dist-packages (from openai) (3.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from openai) (4.64.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=3.0.7->openai) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.3->openai) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.3->openai) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.3->openai) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (3.0.4)
# Building wheels for collected packages: openai
#   Building wheel for openai (PEP 517) ... done
#   Created wheel for openai: filename=openai-0.25.0-py3-none-any.whl size=55880 sha256=477b22131f655c48f6d74bc50a0d26ce105d3b6c553d1faac0c917e29bd57c37
#   Stored in directory: /root/.cache/pip/wheels/19/de/db/e82770b480ec30fd4a6d67108744b9c52be167c04fcf4af7b5
# Successfully built openai
# Installing collected packages: pandas-stubs, openai
# Successfully installed openai-0.25.0 pandas-stubs-1.2.0.62

# %%
import openai

# %%
from openai.embeddings_utils import get_embedding, cosine_similarity

# %%
import os 
openai.api_key = "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" #API key to use open AI

# %%
df
# Out:
#          Adjectives                                             scores  \
# 0             dizzy  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 1           abusive  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 2            somber  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 3           guarded  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4     materialistic  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...             ...                                                ...
# 1128         petite  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1129        fertile  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1130       tiresome  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1131       grateful  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 1132   ill-informed  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
#       compound  pos  neg  neu     type
# 0      -0.2263  0.0  1.0  0.0      NEG
# 1      -0.6369  0.0  1.0  0.0      NEG
# 2      -0.4215  0.0  1.0  0.0      NEG
# 3       0.0000  0.0  0.0  1.0  NEUTRAL
# 4       0.0000  0.0  0.0  1.0  NEUTRAL
# ...        ...  ...  ...  ...      ...
# 1128    0.0000  0.0  0.0  1.0  NEUTRAL
# 1129    0.0000  0.0  0.0  1.0  NEUTRAL
# 1130    0.0000  0.0  0.0  1.0  NEUTRAL
# 1131    0.4588  1.0  0.0  0.0      POS
# 1132    0.0000  0.0  0.0  1.0  NEUTRAL
#
# [1133 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
import numpy as np

# %%
from openai.embeddings_utils import (
    get_embedding,
    distances_from_embeddings,
    tsne_components_from_embeddings,
    chart_from_components,
    indices_of_nearest_neighbors_from_distances,
)

# %%
for idx, row in df.head(5).iterrows():
    print("")
    print(f"Adjectives: {row['Adjectives']}")
    print(f"Positive score: {row['pos']}")
    print(f"Negative score: {row['neg']}")
    print(f"Neutral score: {row['neu']}")
# Out:
# Adjectives: dizzy
# Positive score: 0.0
# Negative score: 1.0
# Neutral score: 0.0
#
# Adjectives: abusive
# Positive score: 0.0
# Negative score: 1.0
# Neutral score: 0.0
#
# Adjectives: somber
# Positive score: 0.0
# Negative score: 1.0
# Neutral score: 0.0
#
# Adjectives: guarded
# Positive score: 0.0
# Negative score: 0.0
# Neutral score: 1.0
#
# Adjectives: materialistic
# Positive score: 0.0
# Negative score: 0.0
# Neutral score: 1.0

# %% [markdown]
# > **A first example**
#
# - The first adjective of our dataset is "dizzy". It refers to the state of someone feeling unsteady or confused (Oxford, 2022). It has been classified as a negative word by the sentiment analysis tool VADER. We will now test the similarity between this word (element[0]=first element of the database ->its index is therefore 0) and external inputs : "men" and "women".
#
# - For that, we will use one of the GPT-3 text similarity models called Davinci.Text similarity models are used to "provide embeddings that capture the semantic similarity of pieces of text" (Open AI, 2022).

# %%
element =df["Adjectives"]
resp = openai.Embedding.create(
    input= ["man", element[0]],#dizzy is at the first row of the database, so its index is 0
    engine="text-similarity-davinci-001")

embedding_a = resp['data'][0]['embedding']
embedding_b = resp['data'][1]['embedding']

similarity_score = np.dot(embedding_a, embedding_b)

# %%
similarity_score
# Out:
# 0.7855535512938464

# %%
resp = openai.Embedding.create(
    input= ["woman", element[0]],
    engine="text-similarity-davinci-001")

embedding_c = resp['data'][0]['embedding']
embedding_d = resp['data'][1]['embedding']

similarity_score2 = np.dot(embedding_c, embedding_d)

# %%
similarity_score2
# Out:
# 0.8130826218403366

# %% [markdown]
# The similarity score associated to the word "dizzy" is slightly higher for "woman" compared to "man". Therefore, we can see that women are more associated than men to this negative word. We explained in the introduction that the GPT-3 language model is trained on several sources, with data scraped from sources like the BBC, NYT, Wikipedia, Reddit... To explain the results on the word "dizzy", we can suppose for that there are more occurences in training dataset of the GPT-3 language model, of situations of women feeling dizzy compared to men. Mimicking its training data, the GPT-3 model therefore indiciate a higher similarity between a woman and being "dizzy", compared to a man.
#
# But it this also the case in the rest of the database ? Are all positve adjectives more associated to men than women ?

# %%
for element in count: #count = database created before, with all positive adjectives
    resp = openai.Embedding.create(
    input= ["woman", element], #to realize the comparaison between the terme 'woman' and each element (each adjective of the database "count")

    engine="text-similarity-davinci-001")

embedding_e = resp['data'][0]['embedding']
embedding_f = resp['data'][1]['embedding']

similarity_score3 = np.dot(embedding_e, embedding_f)

print(similarity_score3)
# Out:
# 0.7796162699050683

# %%
for element in count:
    resp = openai.Embedding.create(
    input= ["man", element], 

    engine="text-similarity-davinci-001")

embedding_g = resp['data'][0]['embedding']
embedding_h = resp['data'][1]['embedding']

similarity_score4 = np.dot(embedding_g, embedding_h)

# %%
print(similarity_score4)
# Out:
# 0.8197550774674068

# %% [markdown]
# It seems that men are more associated to positive adjectives than women, the similarity score is higher for men.<br>

# %% [markdown]
# ## *III. Qualitative Analysis of some adjectives*

# %% [markdown]
# We will use the dataframe "count" (positive adjective) with the similarity scores obtained after performing a text similarity analysis of the adjective with the words "women" and "man".

# %% [markdown]
# ###DataFrame: Count

# %% [markdown]
# "count" is the dataframe that contains all the positive adjectives and its ponctuation according to the sentimental analysis. Since it is a data frame, it contains a lot of data that is not necesary for the text similarity analysis. Therefore, we should first create a list with all the adjectives.

# %% [markdown]
# We will perform two text similarity analysis. One for the word "woman" and another one for the word "man".

# %% [markdown]
# Let's start with the word "woman". Here we are using a for loop to perform the analysis in each adjective of the list "data_set". The comparison of the embeddings of each adjective with the embedding of the word "woman" will be saved in the variable "score_woman".

# %%
nd = pd.DataFrame(columns=['adj'])

# %%
nd['adj'] = count['Adjectives'].head(5)
nd
# Out:
#             adj
# 8     important
# 14       clever
# 19        solid
# 34  intelligent
# 44     romantic

# %%
data_set = nd['adj'].tolist()

# %%
score_woman = [] #here we are performing the text similarity analysis of all the adjectives and the word "woman"
for element in data_set:
  resp = openai.Embedding.create(
      input= ["woman", element],
      engine= "text-similarity-davinci-001")
  embedding_z = resp["data"][0]["embedding"]
  embedding_x = resp["data"][1]["embedding"]
  score_woman.append(np.dot(embedding_z, embedding_x))

# %%
score_woman #here are the scores for each adjective
# Out:
# [0.8116708328353568,
#  0.808350132802933,
#  0.8199700387186553,
#  0.8002970487563639,
#  0.8173558493880251]

# %%
nd["ScoreforWoman"] = score_woman #here we add the scores next to the adjectives in the dataframe

# %%
nd
# Out:
#             adj  ScoreforWoman
# 8     important       0.811671
# 14       clever       0.808350
# 19        solid       0.819970
# 34  intelligent       0.800297
# 44     romantic       0.817356

# %% [markdown]
# Now we have to add the scores next to the adjectives in the dataframe "count".

# %% [markdown]
# We repeat the same process for man. First we do the analysis and we save it in the variable "score_man".

# %%
score_man = [] #here we are performing the text similarity analysis of all the adjectives and the word "woman"
for element in data_set:
  resp = openai.Embedding.create(
      input= ["man", element],
      engine= "text-similarity-davinci-001")
  embedding_t = resp["data"][0]["embedding"]
  embedding_s = resp["data"][1]["embedding"]
  score_man.append(np.dot(embedding_t, embedding_s))

# %%
score_man #just to check the scores
# Out:
# [0.8015599664912756,
#  0.8014368270633281,
#  0.8254361274985565,
#  0.7841480427466108,
#  0.7800212364649024]

# %%
nd["ScoreforMan"] = score_man #here we add the scores next to the adjectives in the dataframe

# %%
nd
# Out:
#             adj  ScoreforWoman  ScoreforMan
# 8     important       0.811671     0.801560
# 14       clever       0.808350     0.801437
# 19        solid       0.819970     0.825436
# 34  intelligent       0.800297     0.784148
# 44     romantic       0.817356     0.780021

# %% [markdown]
# Now we have to add the scores next to the adjectives in the dataframe "count".

# %% [markdown]
# FInally, we sort the score values for woman and men in descending order.

# %%
nd.sort_values(by=["ScoreforWoman","ScoreforMan"],ascending=False)
# Out:
#             adj  ScoreforWoman  ScoreforMan
# 19        solid       0.819970     0.825436
# 44     romantic       0.817356     0.780021
# 8     important       0.811671     0.801560
# 14       clever       0.808350     0.801437
# 34  intelligent       0.800297     0.784148

# %% [markdown]
# ## *IV. Data vizualisation*

# %% [markdown]
# The following part is preseting different graphs in order to show the differences in terms of similarity score between the selected adjectives and the chosen imputs : "man" and "woman".

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.scatter(nd['adj'], nd['ScoreforMan'], c='blue')
plt.scatter(nd['adj'], nd['ScoreforWoman'], c='red')
#To show the gap between the similarity score for men and for women, for a given adjective

# %%
x = nd['adj'].values
y = nd['ScoreforWoman'].values
types = nd.reset_index()['adj'].values

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(x, y)

ax.set_xlabel('Adjectif', fontsize=12)
ax.set_ylabel('Similarity score for Woman', fontsize=12)
ax.set_title('Similarity score', fontsize=16)

for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, color='red')

# %%
x = nd['adj'].values
y = nd['ScoreforMan'].values
types = nd.reset_index()['adj'].values

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(x, y)

ax.set_xlabel('Adjectif', fontsize=12)
ax.set_ylabel('Similarity score for Man', fontsize=12)
ax.set_title('Similarity score', fontsize=16)

for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, color='blue')

# %%
nd_val = nd.sort_values(by=["ScoreforWoman","ScoreforMan"],ascending=True)
nd_val
# Out:
#             adj  ScoreforWoman  ScoreforMan
# 34  intelligent       0.800297     0.784148
# 14       clever       0.808350     0.801437
# 8     important       0.811671     0.801560
# 44     romantic       0.817356     0.780021
# 19        solid       0.819970     0.825436

# %%
plt.plot(nd_val['adj'], nd_val['ScoreforWoman'], c='red')
# To show which adjective is more closely related to the word "Woman"

# %%
x = nd_val['adj'].values
y = nd_val['ScoreforWoman'].values
types = nd_val.reset_index()['adj'].values

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(x, y)

ax.set_xlabel('Adjectif', fontsize=12)
ax.set_ylabel('Similarity score with Woman', fontsize=12)
ax.set_title('Similarity score for woman', fontsize=16)

for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.plot(x, y, color='red')

# %%
nd_val2 = nd.sort_values(by=["ScoreforMan", "ScoreforWoman"],ascending=True)
nd_val2
# Out:
#             adj  ScoreforWoman  ScoreforMan
# 44     romantic       0.817356     0.780021
# 34  intelligent       0.800297     0.784148
# 14       clever       0.808350     0.801437
# 8     important       0.811671     0.801560
# 19        solid       0.819970     0.825436

# %%
plt.plot(nd_val2['adj'], nd_val2['ScoreforMan'], c='blue')

# %%
x = nd_val2['adj'].values
y = nd_val2['ScoreforMan'].values
types = nd_val.reset_index()['adj'].values

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(x, y)

ax.set_xlabel('Adjectif', fontsize=12)
ax.set_ylabel('Similarity score with man', fontsize=12)
ax.set_title('Similarity score for men', fontsize=16)

for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.plot(x, y, color='purple')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 6))
fig.suptitle('Similarity score for Women and for Men')
ax1.plot(nd_val['adj'], nd_val['ScoreforWoman'], c='red')
ax2.plot(nd_val2['adj'], nd_val2['ScoreforMan'], c='blue')
